# %%
import numpy as np
import pandas as pd
import os

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
company_tweets = pd.read_csv("datasets/techTweets/Company_Tweet.csv")
tweet = pd.read_csv("datasets/techTweets/Tweet.csv")

# %%
tweets = pd.merge(company_tweets, tweet, on='tweet_id', how='inner')
tweets.head()
# Out:
#              tweet_id ticker_symbol      writer   post_date  \
# 0  550803612197457920          AAPL  SentiQuant  1420156789
# 1  550803612197457920          AMZN  SentiQuant  1420156789
# 2  550803610825928706          AAPL  SentiQuant  1420156788
# 3  550803610825928706         GOOGL  SentiQuant  1420156788
# 4  550803610825928706          AMZN  SentiQuant  1420156788
#
#                                                 body  comment_num  \
# 0  #TOPTICKERTWEETS $AAPL $IMRS $BABA $EBAY $AMZN...            0
# 1  #TOPTICKERTWEETS $AAPL $IMRS $BABA $EBAY $AMZN...            0
# 2  #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...            0
# 3  #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...            0
# 4  #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...            0
#
#    retweet_num  like_num
# 0            0         1
# 1            0         1
# 2            0         1
# 3            0         1
# 4            0         1

# %%
sentences = tweets['body']
sentences.head()
# Out:
# 0    #TOPTICKERTWEETS $AAPL $IMRS $BABA $EBAY $AMZN...
# 1    #TOPTICKERTWEETS $AAPL $IMRS $BABA $EBAY $AMZN...
# 2    #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...
# 3    #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...
# 4    #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...
# Name: body, dtype: object

# %%
def negativityCheck(sentence):
    return int(analyzer.polarity_scores(sentence)["neg"]>0.5)

# %%
tweets["negative_sentiment"] = pd.DataFrame(sentences.apply(negativityCheck).tolist())
tweets.head(30)
# Out:
#               tweet_id ticker_symbol           writer   post_date  \
# 0   550803612197457920          AAPL       SentiQuant  1420156789
# 1   550803612197457920          AMZN       SentiQuant  1420156789
# 2   550803610825928706          AAPL       SentiQuant  1420156788
# 3   550803610825928706         GOOGL       SentiQuant  1420156788
# 4   550803610825928706          AMZN       SentiQuant  1420156788
# 5   550803225113157632          AAPL      MacHashNews  1420156696
# 6   550802957370159104          AAPL    WaltLightShed  1420156633
# 7   550802855129382912          AAPL     2waystrading  1420156608
# 8   550802745737768960          AAPL  TV_TradingIdeas  1420156582
# 9   550797494188142592          AAPL    Weeklyoptions  1420155330
# 10  550797275786518528          AAPL   Chasing__Stars  1420155278
# 11  550797272686923776          AAPL   Chasing__Stars  1420155277
# 12  550796617444765696          AAPL         TJReazor  1420155121
# 13  550795512899960832          AAPL     GiveBack2011  1420154858
# 14  550795254102638593          AAPL      MacHashNews  1420154796
# 15  550795167318700033          AAPL           fjeddy  1420154775
# 16  550795088821886976          AAPL     MarkDePompeo  1420154757
# 17  550795088821886976         GOOGL     MarkDePompeo  1420154757
# 18  550793298357391360          AAPL       ScoutingGW  1420154330
# 19  550793298357391360          TSLA       ScoutingGW  1420154330
# 20  550793247669231616          AAPL        danshep55  1420154318
# 21  550793108242198528          AAPL     rosnerstocks  1420154284
# 22  550791919815892992          AAPL  UnderGradStocks  1420154001
# 23  550791232738590720          AAPL        Antny2013  1420153837
# 24  550790423888035840          AAPL  marketstocknews  1420153644
# 25  550789798232092672          AAPL     pennstatedan  1420153495
# 26  550782974263037952          AAPL         ramlousl  1420151868
# 27  550782639339470849          AAPL      itassessors  1420151788
# 28  550782127751430144          AAPL         IHPosts2  1420151666
# 29  550782124018515968          AAPL         IHPosts2  1420151666
#
#                                                  body  comment_num  \
# 0   #TOPTICKERTWEETS $AAPL $IMRS $BABA $EBAY $AMZN...            0
# 1   #TOPTICKERTWEETS $AAPL $IMRS $BABA $EBAY $AMZN...            0
# 2   #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...            0
# 3   #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...            0
# 4   #SENTISHIFTUP $K $FB $GOOGL $GS $GOLD $T $AAPL...            0
# 5   Rumor Roundup: What to expect when you're expe...            0
# 6   An $AAPL store line in Sapporo Japan for the "...            2
# 7   $AAPL - Will $AAPL Give Second entry opportuni...            0
# 8   Will $AAPL Give Second entry opportunity? $AAP...            0
# 9   We will book gains in half dozen picks tomorro...            0
# 10  $HMCP Opinions Updated Thursday, January 1, 20...            0
# 11  $OPXS Company Info Updated Thursday, January 1...            0
# 12  If you need to catch up on your market researc...            0
# 13  @MarketRealist and @YahooFinance team up on a ...            0
# 14  Grovemade's wooden accessories bring tech back...            0
# 15  “@complex: a look back to $AAPL 7 years ago. m...            0
# 16  "@CNBC: This is Wall Street's top pick in 2015...            0
# 17  "@CNBC: This is Wall Street's top pick in 2015...            0
# 18  #bluechips like $TSLA, $AAPL, $DIS, $TWTR & NV...            0
# 19  #bluechips like $TSLA, $AAPL, $DIS, $TWTR & NV...            0
# 20  video going out . happy new year . talking $aa...            1
# 21  $BABA Percent Change Updated Thursday, January...            0
# 22  @TheStreet $AAPL by increasing the signs of th...            0
# 23  “In 2014, for every Samsung device activated A...            0
# 24  RT TheStreet: In 2014, for every Samsung devic...            0
# 25  In 2014, for every Samsung device activated Ap...            0
# 26  "@CNBC: This is Wall Street's top pick in 2015...            0
# 27  See how tech companies like Apple, Twitter and...            0
# 28  $TUNG Percent Change Updated Thursday, January...            0
# 29  $NTEK Company Info Updated Thursday, January 1...            0
#
#     retweet_num  like_num  negative_sentiment
# 0             0         1                   0
# 1             0         1                   0
# 2             0         1                   0
# 3             0         1                   0
# 4             0         1                   0
# 5             0         0                   0
# 6             4         4                   0
# 7             0         0                   0
# 8             0         0                   0
# 9             0         1                   0
# 10            0         0                   0
# 11            0         0                   0
# 12            0         0                   0
# 13            0         0                   0
# 14            0         0                   0
# 15            0         0                   0
# 16            0         0                   0
# 17            0         0                   0
# 18            0         3                   0
# 19            0         3                   0
# 20            0         3                   0
# 21            0         1                   0
# 22            0         0                   0
# 23            0         0                   0
# 24            0         0                   0
# 25            0         0                   0
# 26            0         0                   0
# 27            0         0                   0
# 28            0         0                   0
# 29            0         0                   0

# %%
negativeTweets = tweets.loc[tweets["negative_sentiment"]==1]
negativeAppleTweets = negativeTweets.loc[negativeTweets["ticker_symbol"]=='AAPL']
negativeAppleTweets.to_csv('datasets/techTweets/negativeAppleTweets.csv')

# %%
import datetime
negativeAppleTweets['Date'] = pd.to_datetime(negativeAppleTweets['post_date'],unit='s').dt.strftime('%d-%m-%Y')
# Out:
# <ipython-input-23-bcbf7241b00a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negativeAppleTweets['Date'] = pd.to_datetime(negativeAppleTweets['post_date'],unit='s').dt.strftime('%d-%m-%Y')

# %%
negativeAppleTweets.head()
# Out:
#                 tweet_id ticker_symbol         writer   post_date  \
# 2484  551602218307051520          AAPL     CashRocket  1420347191
# 3643  552107054807408640          AAPL      MarcusM08  1420467554
# 4967  552492485617147904          AAPL  RealFanboy101  1420559448
# 4969  552492285724987395          AAPL       shawncj6  1420559400
# 5271  552455561342906368          AAPL      neodocjdg  1420550644
#
#                                     body  comment_num  retweet_num  like_num  \
# 2484  $AVSPY looking brutal.. $AAPL $SPY            0            0         1
# 3643                What the fuck $AAPL?            0            0         0
# 4967             $AAPL pathetic and weak            0            0         0
# 4969                          $AAPL dump            0            0         0
# 5271           $AAPL Dead cat died? $SPY            1            0         0
#
#       negative_sentiment        Date
# 2484                   1  04-01-2015
# 3643                   1  05-01-2015
# 4967                   1  06-01-2015
# 4969                   1  06-01-2015
# 5271                   1  06-01-2015

# %%
negativeAppleTweets.shape
# Out:
# (2178, 10)

# %%
tweetsOnAppleDateCount= negativeAppleTweets["Date"].value_counts()
tweetsOnAppleDateCount = pd.DataFrame(tweetsOnAppleDateCount).reset_index()
tweetsOnAppleDateCount.rename(columns={"index": "Date", "Date": "NegativeTweets"}, inplace=True)
tweetsOnAppleDateCount['Date'] = pd.to_datetime(tweetsOnAppleDateCount['Date'], format='%d-%m-%Y')
tweetsOnAppleDateCount.sort_values("Date", inplace=True)
tweetsOnAppleDateCount.set_index("Date",inplace=True)
tweetsOnAppleDateCount.head()
# Out:
#             NegativeTweets
# Date
# 2015-01-04               1
# 2015-01-05               1
# 2015-01-06               3
# 2015-01-07               2
# 2015-01-08               3

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))

ax= tweetsOnAppleDateCount.loc['2015-01-01':'2020-12-31',"NegativeTweets"].plot()
